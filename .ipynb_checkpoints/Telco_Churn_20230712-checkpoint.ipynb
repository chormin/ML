# %%
pip install category_encoders
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
#from ydata_profiling import ProfileReport
#import dtale
#import dtale.app as dtale_app
#dtale_app.USE_COLAB = True
#import sketch
#import imblearn

# %%
df = pd.read_csv("C:/TNG/Courses/Iverson/Arif/WA_Fn-UseC_-Telco-Customer-Churn.csv", sep=',')
df.head(10)
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
# 5  9305-CDSKC  Female              0      No         No       8          Yes
# 6  1452-KIOVK    Male              0      No        Yes      22          Yes
# 7  6713-OKOMC  Female              0      No         No      10           No
# 8  7892-POOKP  Female              0     Yes         No      28          Yes
# 9  6388-TABGU    Male              0      No        Yes      62          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# ...

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df.shape
# Out:
# (7043, 21)

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %%
df_copy= df.copy()

# %%
duplicate = df_copy[df_copy.duplicated()]
#df_copy.drop_duplicates(inplace=True)
duplicate
# Out:
# Empty DataFrame
# Columns: [customerID, gender, SeniorCitizen, Partner, Dependents, tenure, PhoneService, MultipleLines, InternetService, OnlineSecurity, OnlineBackup, DeviceProtection, TechSupport, StreamingTV, StreamingMovies, Contract, PaperlessBilling, PaymentMethod, MonthlyCharges, TotalCharges, Churn]
# Index: []
#
# [0 rows x 21 columns]

# %%
df_copy.isna().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
print(df_copy.select_dtypes(exclude='number').columns)
# Out:
# Index(['customerID', 'gender', 'Partner', 'Dependents', 'PhoneService',
#        'MultipleLines', 'InternetService', 'OnlineSecurity', 'OnlineBackup',
#        'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies',
#        'Contract', 'PaperlessBilling', 'PaymentMethod', 'TotalCharges',
#        'Churn'],
#       dtype='object')

# %%
print(df_copy.select_dtypes(include='number').columns)
# Out:
# Index(['SeniorCitizen', 'tenure', 'MonthlyCharges'], dtype='object')

# %%
for col in df_copy.columns:
    print(col,len(df_copy[df_copy[col]==' ']))
# Out:
# customerID 0
# gender 0
# SeniorCitizen 0
# Partner 0
# Dependents 0
# tenure 0
# PhoneService 0
# MultipleLines 0
# InternetService 0
# OnlineSecurity 0
# OnlineBackup 0
# DeviceProtection 0
# TechSupport 0
# StreamingTV 0
# StreamingMovies 0
# Contract 0
# PaperlessBilling 0
# PaymentMethod 0
# MonthlyCharges 0
# TotalCharges 11
# Churn 0

# %%
mask = df_copy[df_copy['TotalCharges']==' '].index
df_copy.drop(mask, inplace=True)
df_copy[df_copy['TotalCharges']==' ']
# Out:
# Empty DataFrame
# Columns: [customerID, gender, SeniorCitizen, Partner, Dependents, tenure, PhoneService, MultipleLines, InternetService, OnlineSecurity, OnlineBackup, DeviceProtection, TechSupport, StreamingTV, StreamingMovies, Contract, PaperlessBilling, PaymentMethod, MonthlyCharges, TotalCharges, Churn]
# Index: []
#
# [0 rows x 21 columns]

# %%
#categorical_features = [feature for feature in df_copy.columns if df_copy[feature].dtype=='O']
#numerical_features  =  [feature for feature in df_copy.columns if df_copy[feature].dtype!='O']

# %%
numerical_features = ['tenure','MonthlyCharges','TotalCharges']
categorical_features = []
for col in df_copy.columns:
    if (col not in numerical_features) & (col!='customerID') & (col!='Churn'):
        categorical_features.append(col)
categorical_features
# Out:
# ['gender',
#  'SeniorCitizen',
#  'Partner',
#  'Dependents',
#  'PhoneService',
#  'MultipleLines',
#  'InternetService',
#  'OnlineSecurity',
#  'OnlineBackup',
#  'DeviceProtection',
#  'TechSupport',
#  'StreamingTV',
#  'StreamingMovies',
#  'Contract',
#  'PaperlessBilling',
#  'PaymentMethod']

# %%
for column in categorical_features:
  print(column,df_copy[column].nunique())
# Out:
# gender 2
# SeniorCitizen 2
# Partner 2
# Dependents 2
# PhoneService 2
# MultipleLines 3
# InternetService 3
# OnlineSecurity 3
# OnlineBackup 3
# DeviceProtection 3
# TechSupport 3
# StreamingTV 3
# StreamingMovies 3
# Contract 3
# PaperlessBilling 2
# PaymentMethod 4

# %%
mask = df_copy['InternetService']=='No'
df_copy.loc[mask,['OnlineSecurity','OnlineBackup','DeviceProtection','TechSupport','StreamingTV','StreamingMovies']]
# Out:
#            OnlineSecurity         OnlineBackup     DeviceProtection  \
# 11    No internet service  No internet service  No internet service
# 16    No internet service  No internet service  No internet service
# 21    No internet service  No internet service  No internet service
# 22    No internet service  No internet service  No internet service
# 33    No internet service  No internet service  No internet service
# ...                   ...                  ...                  ...
# 7017  No internet service  No internet service  No internet service
# 7019  No internet service  No internet service  No internet service
# 7020  No internet service  No internet service  No internet service
# 7030  No internet service  No internet service  No internet service
# 7037  No internet service  No internet service  No internet service
#
#               TechSupport          StreamingTV      StreamingMovies
# 11    No internet service  No internet service  No internet service
# ...

# %%
for col in ['OnlineSecurity','OnlineBackup','DeviceProtection','TechSupport','StreamingTV','StreamingMovies']:
    df_copy.loc[mask,col] = 'No'

# %%
for col in categorical_features:
    print(col,df[col].nunique(),df_copy[col].nunique())
# Out:
# gender 2 2
# SeniorCitizen 2 2
# Partner 2 2
# Dependents 2 2
# PhoneService 2 2
# MultipleLines 3 3
# InternetService 3 3
# OnlineSecurity 3 2
# OnlineBackup 3 2
# DeviceProtection 3 2
# TechSupport 3 2
# StreamingTV 3 2
# StreamingMovies 3 2
# Contract 3 3
# PaperlessBilling 2 2
# PaymentMethod 4 4

# %%
dup_temp = df_copy[df_copy.duplicated()]
dup_temp
# Out:
# Empty DataFrame
# Columns: [customerID, gender, SeniorCitizen, Partner, Dependents, tenure, PhoneService, MultipleLines, InternetService, OnlineSecurity, OnlineBackup, DeviceProtection, TechSupport, StreamingTV, StreamingMovies, Contract, PaperlessBilling, PaymentMethod, MonthlyCharges, TotalCharges, Churn]
# Index: []
#
# [0 rows x 21 columns]

# %%
df_copy.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
df_copy.isna().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
df_copy['TotalCharges'] = df_copy['TotalCharges'].astype(float)

# %%
df_copy[numerical_features].describe()
# Out:
#             tenure  MonthlyCharges  TotalCharges
# count  7032.000000     7032.000000   7032.000000
# mean     32.421786       64.798208   2283.300441
# std      24.545260       30.085974   2266.771362
# min       1.000000       18.250000     18.800000
# 25%       9.000000       35.587500    401.450000
# 50%      29.000000       70.350000   1397.475000
# 75%      55.000000       89.862500   3794.737500
# max      72.000000      118.750000   8684.800000

# %%
#plt.subplots(1, 3)
count = 0
for col in numerical_features:
    count = count+1
    plt.subplot(1, 3, count)
    sns.boxplot(data=df_copy[col], orient='vertical', showfliers=True, fliersize=10)
plt.tight_layout()
#plt.show()

# %%
def detect_outlier_iqr(df, columns=None, threshold=1.5):

  # Empty Dataframe
  outlier_df = pd.DataFrame(False, index=df.index, columns=columns)
  for column in columns:
    # Calculate quartiles and IQR
    q1 = df[column].quantile(0.25)
    q3 = df[column].quantile(0.75)
    iqr = q3-q1

    # Calculate the lower and upper bounds for Outlier
    lower_bound = q1 - threshold * iqr
    upper_bound = q3 + threshold * iqr
    #print("For the Feature {} the Upper Bound is {} and Lower Bound is {}".format(column,upper_bound,lower_bound))

    outlier_df[column] = (df[column] < lower_bound) | (df[column]> upper_bound)
  return outlier_df

# %%
#detect_outlier_iqr(df_copy,numerical_features)

# %%
df_copy.shape
# Out:
# (7032, 21)

# %%
def remove_outliers_irq(df,columns=None,threshold=1.5):
  outlier_df = detect_outlier_iqr(df,columns,threshold)
  # Remove Outlier using Boolean Indexing
  for column in columns:
    df = df[~outlier_df[column]]
  return df

# %%
remove_outliers_irq(df_copy,numerical_features)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
df_copy.shape
# Out:
# (7032, 21)

# %%
for col in categorical_features:
    print('\n',col)
    print(df_copy[col].value_counts())
    #df_copy[col].value_counts()
# Out:
#  gender
# Male      3549
# Female    3483
# Name: gender, dtype: int64
#
#  SeniorCitizen
# 0    5890
# 1    1142
# Name: SeniorCitizen, dtype: int64
#
#  Partner
# No     3639
# Yes    3393
# Name: Partner, dtype: int64
#
#  Dependents
# No     4933
# Yes    2099
# Name: Dependents, dtype: int64
#
#  PhoneService
# Yes    6352
# No      680
# Name: PhoneService, dtype: int64
#
#  MultipleLines
# No                  3385
# Yes                 2967
# No phone service     680
# Name: MultipleLines, dtype: int64
#
#  InternetService
# Fiber optic    3096
# DSL            2416
# No             1520
# Name: InternetService, dtype: int64
#
#  OnlineSecurity
# No     5017
# Yes    2015
# Name: OnlineSecurity, dtype: int64
#
#  OnlineBackup
# No     4607
# Yes    2425
# Name: OnlineBackup, dtype: int64
#
#  DeviceProtection
# No     4614
# Yes    2418
# Name: DeviceProtection, dtype: int64
#
#  TechSupport
# No     4992
# Yes    2040
# Name: TechSupport, dtype: int64
#
#  StreamingTV
# ...

# %%
def one_hot_encoding(df,categorical_cols):
  encoded_df = pd.get_dummies(df,columns=categorical_cols,drop_first=True)
  return encoded_df

# %%
from sklearn.preprocessing import LabelEncoder

def label_encoding(df, categorical_cols):
    encoded_df = df.copy()
    label_encoder = LabelEncoder()
    for col in categorical_cols:
        encoded_df[col] = label_encoder.fit_transform(encoded_df[col])
    return encoded_df

# %%
from sklearn.preprocessing import OrdinalEncoder

def ordinal_encoding(df, categorical_cols):
    encoded_df = df.copy()
    ordinal_encoder = OrdinalEncoder()
    encoded_df[categorical_cols] = ordinal_encoder.fit_transform(encoded_df[categorical_cols])
    return encoded_df

# %%
# target Encoding
import category_encoders as ce

def target_encoding(df, categorical_cols, target_col):
    encoded_df = df.copy()
    target_encoder = ce.TargetEncoder(cols=categorical_cols)
    encoded_df[categorical_cols] = target_encoder.fit_transform(encoded_df[categorical_cols], encoded_df[target_col])
    return encoded_df

# %%
df_copy['SeniorCitizen'].replace({0:'no', 1:'yes'}, inplace=True)

# %%
for col in categorical_features:
    print(col,df[col].nunique(),df_copy[col].nunique())
# Out:
# gender 2 2
# SeniorCitizen 2 2
# Partner 2 2
# Dependents 2 2
# PhoneService 2 2
# MultipleLines 3 3
# InternetService 3 3
# OnlineSecurity 3 2
# OnlineBackup 3 2
# DeviceProtection 3 2
# TechSupport 3 2
# StreamingTV 3 2
# StreamingMovies 3 2
# Contract 3 3
# PaperlessBilling 2 2
# PaymentMethod 4 4

# %%
lst = ['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'PhoneService','OnlineSecurity','OnlineBackup','DeviceProtection','TechSupport','StreamingTV','StreamingMovies','PaperlessBilling']
encoded_df = one_hot_encoding(df_copy, lst)

# %%
lst = ['MultipleLines','InternetService','Contract','PaymentMethod']
encoded_df = label_encoding(encoded_df,lst)

# %%
encoded_df.drop('customerID',axis=1,inplace=True)

# %%
encoded_df.head(10)
# Out:
#    tenure  MultipleLines  InternetService  Contract  PaymentMethod  \
# 0       1              1                0         0              2
# 1      34              0                0         1              3
# 2       2              0                0         0              3
# 3      45              1                0         1              0
# 4       2              0                1         0              2
# 5       8              2                1         0              2
# 6      22              2                1         0              1
# 7      10              1                0         0              3
# 8      28              2                1         0              2
# 9      62              0                0         1              0
#
#    MonthlyCharges  TotalCharges Churn  gender_Male  SeniorCitizen_yes  \
# 0           29.85         29.85    No            0                  0
# 1           56.95       1889.50    No            1                  0
# ...

# %%
encoded_df.columns
# Out:
# Index(['tenure', 'MultipleLines', 'InternetService', 'Contract',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn',
#        'gender_Male', 'SeniorCitizen_yes', 'Partner_Yes', 'Dependents_Yes',
#        'PhoneService_Yes', 'OnlineSecurity_Yes', 'OnlineBackup_Yes',
#        'DeviceProtection_Yes', 'TechSupport_Yes', 'StreamingTV_Yes',
#        'StreamingMovies_Yes', 'PaperlessBilling_Yes'],
#       dtype='object')

# %%
encoded_df['Churn'].value_counts()
# Out:
# No     5163
# Yes    1869
# Name: Churn, dtype: int64

# %%
encoded_df['Churn'].replace({'No':0, 'Yes':1}, inplace=True)

# %%
encoded_df['Churn'].value_counts()
# Out:
# 0    5163
# 1    1869
# Name: Churn, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

def z_score_normalization(df):
  scaler = StandardScaler()
  scaled_data = scaler.fit_transform(df)
  scaled_df = pd.DataFrame(scaled_data,columns=df.columns)
  return scaled_df

# %%
from sklearn.preprocessing import MinMaxScaler

def min_max_scaling(df):
  scaler = MinMaxScaler()
  scaled_data = scaler.fit_transform(df)
  scaled_df = pd.DataFrame(scaled_data,columns=df.columns)
  return scaled_df

# %%
from imblearn.under_sampling import RandomUnderSampler
from imblearn.over_sampling import RandomOverSampler

# %%
def handle_imbalance(df,target_column):
  # Seperate the features and the target variable
  X = df.drop(target_column,axis=1)
  y = df[target_column]

  # Instantiate both Under and Over Sampler Class
  under_sampler = RandomUnderSampler()
  over_sampler = RandomOverSampler()

  # Resample the data
  X_resampled, y_resampled = under_sampler.fit_resample(X,y)
  X_resampled, y_resampled = over_sampler.fit_resample(X,y)

  # Create a new balanced Dataframe
  balanced_df = X_resampled.copy()
  balanced_df[target_column] = y_resampled

  return balanced_df

# %%
from sklearn.model_selection import train_test_split

X = min_max_scaling(encoded_df.loc[:, encoded_df.columns!='Churn'])
y = encoded_df['Churn']
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0, train_size= 0.8 )

# %%
#df_train = X_train
#df_train['Churn'] = y_train
df_train = pd.concat([X_train,pd.DataFrame(y_train)])

# %%
scaled_df_z_score = z_score_normalization(df_train_balance)

# %%
scaled_df_z_score.corr()['Churn'].sort_values(ascending=False).plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(15,6))
sns.heatmap(scaled_df_z_score.corr(),cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %%
scaled_df_min_max_score = min_max_scaling(df_train_balance)

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

#X_train = df_train_balance.loc[:, encoded_df.columns!='Churn']
#y_train = df_train_balance['Churn']

rank_features = SelectKBest(score_func=chi2,k=10)
fit_rank = rank_features.fit(X_train,y_train)
df_score = pd.DataFrame(fit_rank.scores_,columns=["Scores"])
df_column = pd.DataFrame(X_train.columns)
df_info = pd.concat([df_column,df_score], axis=1)
df_info.columns=['Features','Scores']
df_info.sort_values(by='Scores', ascending=False)
# Out:
#                 Features      Scores
# 3               Contract  449.890921
# 0                 tenure  195.652848
# 8      SeniorCitizen_yes  122.703715
# 10        Dependents_Yes  113.488771
# 12    OnlineSecurity_Yes  107.131767
# 15       TechSupport_Yes  104.982417
# 18  PaperlessBilling_Yes   86.154793
# 9            Partner_Yes   67.766762
# 6           TotalCharges   60.943389
# 5         MonthlyCharges   41.023468
# 13      OnlineBackup_Yes   26.466057
# 4          PaymentMethod   17.109355
# 14  DeviceProtection_Yes   14.096843
# 17   StreamingMovies_Yes   12.104608
# 16       StreamingTV_Yes   11.413716
# 1          MultipleLines    4.475770
# 2        InternetService    3.385046
# 11      PhoneService_Yes    0.161666
# 7            gender_Male    0.042842

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC

lr = LogisticRegression()
lr.fit(X_train,y_train)

knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train, y_train)

svc = SVC()
svc.fit(X_train, y_train)
# Out:
# SVC()

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import classification_report

# %%
print('lr', accuracy_score(lr.predict(X_test), y_test))
print('knn', accuracy_score(knn.predict(X_test), y_test))
print('svc', accuracy_score(svc.predict(X_test), y_test))
# Out:
# lr 0.8059701492537313
# knn 0.7611940298507462
# svc 0.8024164889836531

# %%
confusion_matrix(y_test, knn.predict(X_test))
# Out:
# array([[887, 151],
#        [185, 184]], dtype=int64)

# %%
plot_confusion_matrix(knn, X_test, y_test, cmap=plt.cm.Blues)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %%
cm = confusion_matrix(y_test, knn.predict(X_test))
color = 'white'
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()
plt.show()

# %%
print('lr', classification_report(y_test, lr.predict(X_test)))
print('knn', classification_report(y_test, knn.predict(X_test)))
print('svc', classification_report(y_test, svc.predict(X_test)))
# Out:
# lr               precision    recall  f1-score   support
#
#            0       0.85      0.90      0.87      1038
#            1       0.66      0.54      0.59       369
#
#     accuracy                           0.81      1407
#    macro avg       0.75      0.72      0.73      1407
# weighted avg       0.80      0.81      0.80      1407
#
# knn               precision    recall  f1-score   support
#
#            0       0.83      0.85      0.84      1038
#            1       0.55      0.50      0.52       369
#
#     accuracy                           0.76      1407
#    macro avg       0.69      0.68      0.68      1407
# weighted avg       0.75      0.76      0.76      1407
#
# svc               precision    recall  f1-score   support
#
#            0       0.83      0.92      0.87      1038
#            1       0.68      0.47      0.56       369
#
#     accuracy                           0.80      1407
#    macro avg       0.75      0.70      0.71      1407
# ...
